# %% [markdown]
# <a href="https://colab.research.google.com/github/Ilker-Findik/1-Nasa/blob/main/4_Nasa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Kurulum
# !pip install earthaccess
# !pip install netCDF4

# Temel kullanım
import earthaccess
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import netCDF4 as nc

# NASA Earthdata giriş (ücretsiz hesap gerekli)
auth = earthaccess.login(persist=True)
# Out:
# Requirement already satisfied: earthaccess in /usr/local/lib/python3.12/dist-packages (0.15.1)
# Requirement already satisfied: fsspec>=2025.2 in /usr/local/lib/python3.12/dist-packages (from earthaccess) (2025.9.0)
# Requirement already satisfied: importlib-resources>=6.3.2 in /usr/local/lib/python3.12/dist-packages (from earthaccess) (6.5.2)
# Requirement already satisfied: multimethod>=1.8 in /usr/local/lib/python3.12/dist-packages (from earthaccess) (2.0)
# Requirement already satisfied: pqdm>=0.1 in /usr/local/lib/python3.12/dist-packages (from earthaccess) (0.2.0)
# Requirement already satisfied: python-cmr>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from earthaccess) (0.13.0)
# Requirement already satisfied: requests>=2.26 in /usr/local/lib/python3.12/dist-packages (from earthaccess) (2.32.4)
# Requirement already satisfied: s3fs>=2025.2 in /usr/local/lib/python3.12/dist-packages (from earthaccess) (2025.9.0)
# Requirement already satisfied: tenacity>=9.0 in /usr/local/lib/python3.12/dist-packages (from earthaccess) (9.1.2)
# Requirement already satisfied: tinynetrc>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from earthaccess) (1.3.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from earthaccess) (4.15.0)
# Requirement already satisfied: bounded-pool-executor in /usr/local/lib/python3.12/dist-packages (from pqdm>=0.1->earthaccess) (0.0.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from pqdm>=0.1->earthaccess) (4.67.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from python-cmr>=0.10.0->earthaccess) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26->earthaccess) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26->earthaccess) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26->earthaccess) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26->earthaccess) (2025.8.3)
# Requirement already satisfied: aiobotocore<3.0.0,>=2.5.4 in /usr/local/lib/python3.12/dist-packages (from s3fs>=2025.2->earthaccess) (2.24.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from s3fs>=2025.2->earthaccess) (3.12.15)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2025.2->earthaccess) (0.12.0)
# Requirement already satisfied: botocore<1.40.19,>=1.40.15 in /usr/local/lib/python3.12/dist-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2025.2->earthaccess) (1.40.18)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2025.2->earthaccess) (1.0.1)
# Requirement already satisfied: multidict<7.0.0,>=6.0.0 in /usr/local/lib/python3.12/dist-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2025.2->earthaccess) (6.6.4)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in /usr/local/lib/python3.12/dist-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2025.2->earthaccess) (1.17.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2025.2->earthaccess) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2025.2->earthaccess) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2025.2->earthaccess) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2025.2->earthaccess) (1.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2025.2->earthaccess) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2025.2->earthaccess) (1.20.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil<3.0.0,>=2.8.2->python-cmr>=0.10.0->earthaccess) (1.17.0)
# Requirement already satisfied: netCDF4 in /usr/local/lib/python3.12/dist-packages (1.7.2)
# Requirement already satisfied: cftime in /usr/local/lib/python3.12/dist-packages (from netCDF4) (1.6.4.post1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from netCDF4) (2025.8.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from netCDF4) (2.0.2)

# %%
results = earthaccess.search_data(
    short_name="TEMPO_NO2_L3",
    version="V03",
    temporal=("2024-09-01 00:00:00", "2024-09-01 23:59:59"),
    bounding_box=(-96.0, 32.0, -89.0, 44.0)
)

# Verileri indirme
files = earthaccess.download(results, local_path="./tempo_data")
# Out:
# QUEUEING TASKS | :   0%|          | 0/18 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/18 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/18 [00:00<?, ?it/s]

# %%
df=pd.read_csv('Nasa.csv')

# %%
df.columns
# Out:
# Index(['Temperature', 'Humidity', 'PM2.5', 'PM10', 'NO2', 'SO2', 'CO',
#        'Proximity_to_Industrial_Areas', 'Population_Density', 'Air Quality'],
#       dtype='object')

# %%
df['Air Quality'].unique()
# Out:
# array(['Moderate', 'Good', 'Hazardous', 'Poor'], dtype=object)

# %%
df.head(3)
# Out:
#    Temperature  Humidity  PM2.5  PM10   NO2   SO2    CO  \
# 0         29.8      59.1    5.2  17.9  18.9   9.2  1.72
# 1         28.3      75.6    2.3  12.2  30.8   9.7  1.64
# 2         23.1      74.7   26.7  33.8  24.4  12.6  1.63
#
#    Proximity_to_Industrial_Areas  Population_Density Air Quality
# 0                            6.3                 319    Moderate
# 1                            6.0                 611    Moderate
# 2                            5.2                 619    Moderate

# %%
df['Population_Density'].mean()
# Out:
# np.float64(497.4238)

# %%
df.tail()
# Out:
#       Temperature  Humidity  PM2.5   PM10   NO2   SO2    CO  \
# 4995         40.6      74.1  116.0  126.7  45.5  25.7  2.11
# 4996         28.1      96.9    6.9   25.0  25.3  10.8  1.54
# 4997         25.9      78.2   14.2   22.1  34.8   7.8  1.63
# 4998         25.3      44.4   21.4   29.0  23.7   5.7  0.89
# 4999         24.1      77.9   81.7   94.3  23.2  10.5  1.38
#
#       Proximity_to_Industrial_Areas  Population_Density Air Quality
# 4995                            2.8                 765   Hazardous
# 4996                            5.7                 709    Moderate
# 4997                            9.6                 379    Moderate
# 4998                           11.6                 241        Good
# 4999                            8.3                 461    Moderate

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Temperature                    5000 non-null   float64
#  1   Humidity                       5000 non-null   float64
#  2   PM2.5                          5000 non-null   float64
#  3   PM10                           5000 non-null   float64
#  4   NO2                            5000 non-null   float64
#  5   SO2                            5000 non-null   float64
#  6   CO                             5000 non-null   float64
#  7   Proximity_to_Industrial_Areas  5000 non-null   float64
#  8   Population_Density             5000 non-null   int64
#  9   Air Quality                    5000 non-null   object
# dtypes: float64(8), int64(1), object(1)
# memory usage: 390.8+ KB

# %%
df = df.rename(columns={'Air Quality': 'AirQuality'})
df = df.rename(columns={'PM2.5': 'PM2_5'})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Temperature                    5000 non-null   float64
#  1   Humidity                       5000 non-null   float64
#  2   PM2_5                          5000 non-null   float64
#  3   PM10                           5000 non-null   float64
#  4   NO2                            5000 non-null   float64
#  5   SO2                            5000 non-null   float64
#  6   CO                             5000 non-null   float64
#  7   Proximity_to_Industrial_Areas  5000 non-null   float64
#  8   Population_Density             5000 non-null   int64
#  9   AirQuality                     5000 non-null   object
# dtypes: float64(8), int64(1), object(1)
# memory usage: 390.8+ KB

# %%
df['AirQuality'].unique()
# Out:
# array(['Moderate', 'Good', 'Hazardous', 'Poor'], dtype=object)

# %%
df.isnull().sum()
# Out:
# Temperature                      0
# Humidity                         0
# PM2_5                            0
# PM10                             0
# NO2                              0
# SO2                              0
# CO                               0
# Proximity_to_Industrial_Areas    0
# Population_Density               0
# AirQuality                       0
# dtype: int64

# %%
df=df.drop(columns='Proximity_to_Industrial_Areas')

# %%
y = df['AirQuality']
x = df.drop('AirQuality', axis=1)

# %%
df.head()
# Out:
#    Temperature  Humidity  PM2_5  PM10   NO2   SO2    CO  Population_Density  \
# 0         29.8      59.1    5.2  17.9  18.9   9.2  1.72                 319
# 1         28.3      75.6    2.3  12.2  30.8   9.7  1.64                 611
# 2         23.1      74.7   26.7  33.8  24.4  12.6  1.63                 619
# 3         27.1      39.1    6.1   6.3  13.5   5.3  1.15                 551
# 4         26.5      70.7    6.9  16.0  21.9   5.6  1.01                 303
#
#   AirQuality
# 0   Moderate
# 1   Moderate
# 2   Moderate
# 3       Good
# 4       Good

# %%
pd.get_dummies(df,columns=['AirQuality'],drop_first=True)
# Out:
#       Temperature  Humidity  PM2_5   PM10   NO2   SO2    CO  \
# 0            29.8      59.1    5.2   17.9  18.9   9.2  1.72
# 1            28.3      75.6    2.3   12.2  30.8   9.7  1.64
# 2            23.1      74.7   26.7   33.8  24.4  12.6  1.63
# 3            27.1      39.1    6.1    6.3  13.5   5.3  1.15
# 4            26.5      70.7    6.9   16.0  21.9   5.6  1.01
# ...           ...       ...    ...    ...   ...   ...   ...
# 4995         40.6      74.1  116.0  126.7  45.5  25.7  2.11
# 4996         28.1      96.9    6.9   25.0  25.3  10.8  1.54
# 4997         25.9      78.2   14.2   22.1  34.8   7.8  1.63
# 4998         25.3      44.4   21.4   29.0  23.7   5.7  0.89
# 4999         24.1      77.9   81.7   94.3  23.2  10.5  1.38
#
#       Population_Density  AirQuality_Hazardous  AirQuality_Moderate  \
# 0                    319                 False                 True
# 1                    611                 False                 True
# 2                    619                 False                 True
# 3                    551                 False                False
# 4                    303                 False                False
# ...                  ...                   ...                  ...
# 4995                 765                  True                False
# 4996                 709                 False                 True
# 4997                 379                 False                 True
# 4998                 241                 False                False
# 4999                 461                 False                 True
#
#       AirQuality_Poor
# 0               False
# 1               False
# 2               False
# 3               False
# 4               False
# ...               ...
# 4995            False
# 4996            False
# 4997            False
# 4998            False
# 4999            False
#
# [5000 rows x 11 columns]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
rf = RandomForestClassifier()
model = rf.fit(x_train, y_train)

# %%
model.score(x_test, y_test)
# Out:
# 0.939

# %%
import pickle

# %%
with open('modelnasa.pkl', 'wb') as f:
    pickle.dump({
      'model': rf,
      'scaler': scaler},
      f)

# %%
pd.DataFrame(x_train).to_csv('testdatanasa.csv',index =False)
